# %% [markdown]
# <a href="https://colab.research.google.com/github/arunvithyasegar/News_sentiment_Analysis/blob/main/News_Sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests pandas nltk textblob feedparser plotly newspaper3k pycountry --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 39.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 6.2 MB/s eta 0:00:00
#   Building wheel for tinysegmenter (setup.py) ... done
#   Building wheel for feedfinder2 (setup.py) ... done
#   Building wheel for jieba3k (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done

# %%
import requests
import pandas as pd
import re
from datetime import datetime
import time
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import feedparser
import pycountry
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Cell 3: Set up basic variables

# Define search keywords and headers for web requests
keywords = ['electronics', 'semiconductor', 'manufacturing', 'chip', 'technology']
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
news_data = []  # Empty list to store collected news
newsapi_key = "pub_86076086703c94c2637e240672a4a90a30ad9"

# Create a list of country names for location extraction
country_list = [country.name for country in pycountry.countries]

# %%
# Cell 4: Define a function to extract country mentions from text
def extract_countries(text):
    """Find country names mentioned in the text"""
    found_countries = []
    for country in country_list:
        if re.search(r'\b' + re.escape(country) + r'\b', text, re.IGNORECASE):
            found_countries.append(country)
    return ', '.join(found_countries) if found_countries else 'Not specified'

# %%
# Cell 5: Scrape news from Google News RSS feed
print("Scraping Google News RSS feeds...")
google_news = []

for keyword in keywords:
    feed_url = f'https://news.google.com/rss/search?q={keyword}+business&hl=en-US&gl=US&ceid=US:en'
    news_feed = feedparser.parse(feed_url)

    for entry in news_feed.entries[:5]:  # Get first 5 from each keyword
        google_news.append({
            'title': entry.title,
            'url': entry.link,
            'timestamp': datetime.strptime(entry.published, '%a, %d %b %Y %H:%M:%S %Z').strftime('%Y-%m-%d %H:%M:%S'),
            'source': 'Google News'
        })
        time.sleep(0.5)

print(f"Collected {len(google_news)} articles from Google News")
# Out:
# Scraping Google News RSS feeds...
# Collected 25 articles from Google News

# %%
# Cell 6: Get news from NewsAPI
print("Getting news from NewsAPI...")
newsapi_articles = []

# NewsAPI endpoint for the free plan
url = f'https://newsdata.io/api/1/news?apikey={newsapi_key}&q=electronics OR semiconductor OR manufacturing&language=en&category=business,technology'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    articles = data.get('results', [])

    for article in articles:
        if article.get('title') and article.get('link'):
            newsapi_articles.append({
                'title': article['title'],
                'url': article['link'],
                'timestamp': article.get('pubDate', 'Unknown'),
                'source': article.get('source_id', 'NewsAPI')
            })

print(f"Collected {len(newsapi_articles)} articles from NewsAPI")
# Out:
# Getting news from NewsAPI...
# Collected 10 articles from NewsAPI

# %%
# Cell 7: Combine all news sources and remove duplicates
print("Combining all news sources...")
all_articles = google_news + newsapi_articles

# Remove duplicates based on title
unique_articles = []
unique_titles = set()

for article in all_articles:
    if article['title'] not in unique_titles:
        unique_titles.add(article['title'])
        unique_articles.append(article)
# Limit to 20 articles
final_articles = unique_articles[:20]
print(f"Selected {len(final_articles)} unique articles for analysis")
# Out:
# Combining all news sources...
# Selected 20 unique articles for analysis

# %%
# Cell 8: Extract country mentions and create the final dataset
print("Extracting country mentions...")
for article in final_articles:
    # Extract country information
    countries = extract_countries(article['title'])

    # Add to news data
    news_data.append({
        'title': article['title'],
        'url': article['url'],
        'timestamp': article['timestamp'],
        'source': article.get('source', 'Unknown'),
        'country': countries
    })
# Create a pandas DataFrame
news_df = pd.DataFrame(news_data)
print("News data collected and organized into DataFrame")
# Out:
# Extracting country mentions...
# News data collected and organized into DataFrame

# %%
# Cell 9: Set up and perform sentiment analysis
print("Performing sentiment analysis...")
# Initialize the VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to determine sentiment category based on compound score
def get_sentiment_category(compound_score):
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# Analyze each headline
news_df['sentiment_score'] = news_df['title'].apply(lambda x: sid.polarity_scores(x)['compound'])
news_df['sentiment'] = news_df['sentiment_score'].apply(get_sentiment_category)

print("Sentiment analysis complete")
print(f"Sentiment distribution: Positive: {sum(news_df['sentiment'] == 'Positive')}, " +
      f"Neutral: {sum(news_df['sentiment'] == 'Neutral')}, " +
      f"Negative: {sum(news_df['sentiment'] == 'Negative')}")
# Out:
# Performing sentiment analysis...
# Sentiment analysis complete
# Sentiment distribution: Positive: 4, Neutral: 28, Negative: 8

# %%
# Cell 10: Display the collected news data
print("Displaying collected news data:")
news_df
# Out:
# Displaying collected news data:
#                                                 title  \
# 0   Electronics company posts bill with over $36K ...
# 1   Samsung | History, Consumer Products, Leadersh...
# 2   DuPont Announces CEO and Non-Executive Chair f...
# 3   Samsung Electronics says unit Harman acquires ...
# 4   DuPont Files Form 10 To Spin Off Electronics B...
# 5   A timeline of the U.S. semiconductor market in...
# 6   Huawei and other Chinese chip firms are catchi...
# 7   Jim Cramer Says Taiwan Semiconductor Manufactu...
# 8   US Chip Tariffs: How Might Europe Respond? - C...
# 9   A tale of two cities: Korea’s red tape slows S...
# 10  Chinese Factories Are Moving Manufacturing to ...
# 11  'Cincinnati is on the map': Manufacturing comp...
# 12  Two RV companies to close manufacturing plants...
# 13  Roche pledges nearly $300M to establish new Va...
# 14  Guiding a Manufacturing Business through Tarif...
# 15  Trump to change controversial Biden-era restri...
# 16  Samsung says trade turmoil raises chip busines...
# 17  The Stealthy Lab Cooking Up Amazon’s Secret Sa...
# 18  Nvidia Stock Wobbles On Uncertainty Over Trump...
# 19  ‘Tone deaf’: US tech company responsible for g...
# 20  Electronics company posts bill with over $36K ...
# 21  Samsung | History, Consumer Products, Leadersh...
# 22  DuPont Announces CEO and Non-Executive Chair f...
# 23  Samsung Electronics says unit Harman acquires ...
# 24  DuPont Files Form 10 To Spin Off Electronics B...
# 25  A timeline of the U.S. semiconductor market in...
# 26  Huawei and other Chinese chip firms are catchi...
# 27  Jim Cramer Says Taiwan Semiconductor Manufactu...
# 28  US Chip Tariffs: How Might Europe Respond? - C...
# 29  A tale of two cities: Korea’s red tape slows S...
# 30  Chinese Factories Are Moving Manufacturing to ...
# 31  'Cincinnati is on the map': Manufacturing comp...
# 32  Two RV companies to close manufacturing plants...
# 33  Roche pledges nearly $300M to establish new Va...
# 34  Guiding a Manufacturing Business through Tarif...
# 35  Trump to change controversial Biden-era restri...
# 36  Samsung says trade turmoil raises chip busines...
# 37  The Stealthy Lab Cooking Up Amazon’s Secret Sa...
# 38  Nvidia Stock Wobbles On Uncertainty Over Trump...
# 39  ‘Tone deaf’: US tech company responsible for g...
#
#                                                   url            timestamp  \
# 0   https://news.google.com/rss/articles/CBMiowFBV...  2025-05-09 20:06:34
# 1   https://news.google.com/rss/articles/CBMiYkFVX...  2025-05-08 07:13:00
# 2   https://news.google.com/rss/articles/CBMiwwFBV...  2025-03-17 10:50:10
# 3   https://news.google.com/rss/articles/CBMiigFBV...  2025-05-06 21:06:35
# 4   https://news.google.com/rss/articles/CBMingFBV...  2025-04-25 07:00:00
# 5   https://news.google.com/rss/articles/CBMijgFBV...  2025-05-10 14:00:00
# 6   https://news.google.com/rss/articles/CBMipAFBV...  2025-05-08 13:01:04
# 7   https://news.google.com/rss/articles/CBMiigFBV...  2025-05-09 14:23:31
# 8   https://news.google.com/rss/articles/CBMidEFVX...  2025-05-09 16:18:05
# 9   https://news.google.com/rss/articles/CBMi_AFBV...  2025-05-09 07:29:56
# 10  https://news.google.com/rss/articles/CBMiggFBV...  2025-05-10 04:00:06
# 11  https://news.google.com/rss/articles/CBMi4wJBV...  2025-05-09 22:56:11
# 12  https://news.google.com/rss/articles/CBMiywFBV...  2025-05-08 19:13:00
# 13  https://news.google.com/rss/articles/CBMiqgFBV...  2025-05-09 14:06:14
# 14  https://news.google.com/rss/articles/CBMiuwFBV...  2025-05-08 15:36:11
# 15  https://news.google.com/rss/articles/CBMifkFVX...  2025-05-08 16:08:00
# 16  https://news.google.com/rss/articles/CBMioAFBV...  2025-04-30 07:00:00
# 17  https://news.google.com/rss/articles/CBMijwFBV...  2025-05-10 01:00:00
# 18  https://news.google.com/rss/articles/CBMinAFBV...  2025-05-08 20:09:00
# 19  https://news.google.com/rss/articles/CBMijgFBV...  2025-05-09 07:16:00
# 20  https://news.google.com/rss/articles/CBMiowFBV...  2025-05-09 20:06:34
# 21  https://news.google.com/rss/articles/CBMiYkFVX...  2025-05-08 07:13:00
# 22  https://news.google.com/rss/articles/CBMiwwFBV...  2025-03-17 10:50:10
# 23  https://news.google.com/rss/articles/CBMiigFBV...  2025-05-06 21:06:35
# 24  https://news.google.com/rss/articles/CBMingFBV...  2025-04-25 07:00:00
# 25  https://news.google.com/rss/articles/CBMijgFBV...  2025-05-10 14:00:00
# 26  https://news.google.com/rss/articles/CBMipAFBV...  2025-05-08 13:01:04
# 27  https://news.google.com/rss/articles/CBMiigFBV...  2025-05-09 14:23:31
# 28  https://news.google.com/rss/articles/CBMidEFVX...  2025-05-09 16:18:05
# 29  https://news.google.com/rss/articles/CBMi_AFBV...  2025-05-09 07:29:56
# 30  https://news.google.com/rss/articles/CBMiggFBV...  2025-05-10 04:00:06
# 31  https://news.google.com/rss/articles/CBMi4wJBV...  2025-05-09 22:56:11
# 32  https://news.google.com/rss/articles/CBMiywFBV...  2025-05-08 19:13:00
# 33  https://news.google.com/rss/articles/CBMiqgFBV...  2025-05-09 14:06:14
# 34  https://news.google.com/rss/articles/CBMiuwFBV...  2025-05-08 15:36:11
# 35  https://news.google.com/rss/articles/CBMifkFVX...  2025-05-08 16:08:00
# 36  https://news.google.com/rss/articles/CBMioAFBV...  2025-04-30 07:00:00
# 37  https://news.google.com/rss/articles/CBMijwFBV...  2025-05-10 01:00:00
# 38  https://news.google.com/rss/articles/CBMinAFBV...  2025-05-08 20:09:00
# 39  https://news.google.com/rss/articles/CBMijgFBV...  2025-05-09 07:16:00
#
#          source        country  sentiment_score sentiment
# 0   Google News  Not specified           0.0000   Neutral
# 1   Google News  Not specified           0.0000   Neutral
# 2   Google News  Not specified           0.0000   Neutral
# 3   Google News  Not specified           0.0000   Neutral
# 4   Google News  Not specified           0.0000   Neutral
# 5   Google News  Not specified           0.0000   Neutral
# 6   Google News  Not specified           0.0000   Neutral
# 7   Google News  Not specified          -0.2263  Negative
# 8   Google News  Not specified           0.0000   Neutral
# 9   Google News  Not specified           0.0000   Neutral
# 10  Google News  Not specified           0.1779  Positive
# 11  Google News  Not specified           0.0000   Neutral
# 12  Google News  Not specified           0.0000   Neutral
# 13  Google News          China           0.0000   Neutral
# 14  Google News  Not specified           0.0000   Neutral
# 15  Google News  Not specified          -0.2023  Negative
# 16  Google News  Not specified          -0.4588  Negative
# 17  Google News  Not specified          -0.0258   Neutral
# 18  Google News  Not specified          -0.3400  Negative
# 19  Google News  Not specified           0.0516  Positive
# 20  Google News  Not specified           0.0000   Neutral
# 21  Google News  Not specified           0.0000   Neutral
# 22  Google News  Not specified           0.0000   Neutral
# 23  Google News  Not specified           0.0000   Neutral
# 24  Google News  Not specified           0.0000   Neutral
# 25  Google News  Not specified           0.0000   Neutral
# 26  Google News  Not specified           0.0000   Neutral
# 27  Google News  Not specified          -0.2263  Negative
# 28  Google News  Not specified           0.0000   Neutral
# 29  Google News  Not specified           0.0000   Neutral
# 30  Google News  Not specified           0.1779  Positive
# 31  Google News  Not specified           0.0000   Neutral
# 32  Google News  Not specified           0.0000   Neutral
# 33  Google News          China           0.0000   Neutral
# 34  Google News  Not specified           0.0000   Neutral
# 35  Google News  Not specified          -0.2023  Negative
# 36  Google News  Not specified          -0.4588  Negative
# 37  Google News  Not specified          -0.0258   Neutral
# 38  Google News  Not specified          -0.3400  Negative
# 39  Google News  Not specified           0.0516  Positive

# %%
# Cell 11: Create a bar chart for sentiment distribution using Plotly
print("Creating sentiment distribution chart...")
sentiment_counts = news_df['sentiment'].value_counts().reset_index()
sentiment_counts.columns = ['Sentiment', 'Count']

# Define a color map for sentiments
color_map = {'Positive': '#4CAF50', 'Neutral': '#2196F3', 'Negative': '#F44336'}

# Create the bar chart
fig = px.bar(
    sentiment_counts,
    x='Sentiment',
    y='Count',
    title='Sentiment Distribution of News Headlines',
    color='Sentiment',
    color_discrete_map=color_map,
    text='Count'
)

fig.update_layout(
    xaxis_title='Sentiment Category',
    yaxis_title='Number of Headlines',
    plot_bgcolor='rgba(0,0,0,0)',
    font=dict(size=14),
    height=500
)

fig.update_traces(textposition='auto')
fig.show()
# Out:
# Creating sentiment distribution chart...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b9b6999c-66dd-4550-8ac5-c59995f1b523" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9b6999c-66dd-4550-8ac5-c59995f1b523")) {                    Plotly.newPlot(                        "b9b6999c-66dd-4550-8ac5-c59995f1b523",                        [{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neutral","marker":{"color":"#2196F3","pattern":{"shape":""}},"name":"Neutral","offsetgroup":"Neutral","orientation":"v","showlegend":true,"text":[28.0],"textposition":"auto","x":["Neutral"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Negative","marker":{"color":"#F44336","pattern":{"shape":""}},"name":"Negative","offsetgroup":"Negative","orientation":"v","showlegend":true,"text":[8.0],"textposition":"auto","x":["Negative"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sentiment=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Positive","marker":{"color":"#4CAF50","pattern":{"shape":""}},"name":"Positive","offsetgroup":"Positive","orientation":"v","showlegend":true,"text":[4.0],"textposition":"auto","x":["Positive"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"], ...

# %%
# Cell 12: Create an interactive table of the news articles
print("Creating interactive news table...")
table_fig = go.Figure(data=[go.Table(
    header=dict(
        values=['<b>Title</b>', '<b>Timestamp</b>', '<b>Source</b>', '<b>Country</b>', '<b>Sentiment</b>'],
        fill_color='#2196F3',
        align='left',
        font=dict(color='white', size=12)
    ),
    cells=dict(
        values=[
            news_df['title'],
            news_df['timestamp'],
            news_df['source'],
            news_df['country'],
            news_df['sentiment']
        ],
        fill_color=[
            ['white'] * len(news_df),
            ['white'] * len(news_df),
            ['white'] * len(news_df),
            ['white'] * len(news_df),
            [
                '#4CAF50' if sentiment == 'Positive' else
                '#F44336' if sentiment == 'Negative' else '#FFC107'
                for sentiment in news_df['sentiment']
            ]
        ],
        align='left',
        font=dict(size=11),
        height=30
    )
)])

table_fig.update_layout(
    title='Collected News Articles',
    margin=dict(l=10, r=10, t=30, b=10),
    height=600
)

table_fig.show()
# Out:
# Creating interactive news table...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="158eba29-6416-49d5-a52c-ed3bc952ee82" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("158eba29-6416-49d5-a52c-ed3bc952ee82")) {                    Plotly.newPlot(                        "158eba29-6416-49d5-a52c-ed3bc952ee82",                        [{"cells":{"align":"left","fill":{"color":[["white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white"],["white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white"],["white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white"],["white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white","white"],["#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#F44336","#FFC107","#FFC107","#4CAF50","#FFC107","#FFC107","#FFC107","#FFC107","#F44336","#F44336","#FFC107","#F44336","#4CAF50","#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#FFC107","#F44336","#FFC107","#FFC107","#4CAF50","#FFC107","#FFC107","#FFC107","#FFC107","#F44336","#F44336","#FFC107","#F44336","#4CAF50"]]},"font":{"size":11},"height":30,"values":[["Electronics company posts bill with over $36K tariff charge, announces price increases - USA Today","Samsung | History, Consumer Products, Leadership, & Facts - Britannica","DuPont Announces CEO and Non-Executive Chair for the Planned Independent Electronics Company - DuPont","Samsung Electronics says unit Harman acquires Masimo's audio business for $350 million - Yahoo Finance","DuPont Files Form 10 To Spin Off Electronics Business As Standalone Company - Nasdaq","A timeline of the U.S. semiconductor market in 2025 - TechCrunch","Huawei and other Chinese chip firms are catching up fast - The Economist","Jim Cramer Says Taiwan Semiconductor Manufacturing Company Limited (TSM) Is ‘So Low’ - Yahoo Finance","US Chip Tariffs: How Might Europe Respond? - Center for European Policy Analysis (CEPA)","A tale of two cities: Korea’s red tape slows SK hynix as U.S. moves faster - Korea JoongAng Daily","Chinese Factories Are Moving Manufacturing to Vietnam to Escape Trump’s Tariffs - The New York Times","'Cincinnati is on the map': Manufacturing company opening in historic local site - WKRC","Two RV companies to close manufacturing plants in LaGrange County, impacting more than 300 workers - 21Alive","Roche pledges nearly $300M to establish new Vabysmo production plant in China - Fierce Pharma","Guiding a Manufacturing Business through Tariffs: Webinar Recap - IndustryWeek","Trump to change controversial Biden-era restrictions on AI chip exports - CNN","Samsung says trade turmoil raises chip business volatilities, may hit phone demand - Reuters","The Stealthy Lab Cooking Up Amazon’s Secret Sauce - WSJ","Nvidia Stock Wobbles On Uncertainty Over ...

# %%
# Cell 13: Create a comprehensive dashboard with multiple visualizations
print("Creating dashboard...")

# Create a source distribution pie chart
source_counts = news_df['source'].value_counts().reset_index()
source_counts.columns = ['Source', 'Count']

fig_dashboard = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Sentiment Distribution of News Headlines", "News Source Distribution"),
    specs=[[{"type": "bar"}], [{"type": "pie"}]],
    vertical_spacing=0.3,
    row_heights=[0.5, 0.5]
)

# Add sentiment distribution bar chart (top)
fig_dashboard.add_trace(
    go.Bar(
        x=sentiment_counts['Sentiment'],
        y=sentiment_counts['Count'],
        marker_color=[color_map[sentiment] for sentiment in sentiment_counts['Sentiment']],
        text=sentiment_counts['Count'],
        textposition='auto',
        name='Sentiment Count'
    ),
    row=1, col=1
)

# Add source distribution pie chart (bottom)
fig_dashboard.add_trace(
    go.Pie(
        labels=source_counts['Source'],
        values=source_counts['Count'],
        hole=0.4,
        name='Source Distribution'
    ),
    row=2, col=1
)

# Update layout
fig_dashboard.update_layout(
    height=800,
    showlegend=False,
    title_text="News Sentiment Analysis Dashboard",
    title_font_size=20,
    plot_bgcolor='rgba(0,0,0,0)'
)

fig_dashboard.show()
# Out:
# Creating dashboard...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5439c587-8f86-4974-ab2b-bdd9a0c299fb" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5439c587-8f86-4974-ab2b-bdd9a0c299fb")) {                    Plotly.newPlot(                        "5439c587-8f86-4974-ab2b-bdd9a0c299fb",                        [{"marker":{"color":["#2196F3","#F44336","#4CAF50"]},"name":"Sentiment Count","text":[28.0,8.0,4.0],"textposition":"auto","x":["Neutral","Negative","Positive"],"y":[28,8,4],"type":"bar","xaxis":"x","yaxis":"y"},{"hole":0.4,"labels":["Google News"],"name":"Source Distribution","values":[40],"type":"pie","domain":{"x":[0.0,1.0],"y":[0.0,0.35]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type" ...

# %%
# Cell 14: Save the data to CSV and HTML files for future reference
news_df.to_csv("scraped_news_data.csv", index=False)
fig.write_html("sentiment_distribution.html")
table_fig.write_html("news_table.html")
fig_dashboard.write_html("news_dashboard.html")

print("Analysis complete! Results saved to CSV and HTML files.")
# Out:
# Analysis complete! Results saved to CSV and HTML files.
